# %% [markdown]
# # 01 — Core VaR / CVaR Validation
#
# Skeleton notebook for validating the Phase 1 risk engine against synthetic and live data.
#
# Sections to fill in later:
# 1. Load configuration and price data
# 2. Compute returns and portfolio aggregate
# 3. Compute VaR / CVaR with all methods
# 4. Cross-check Gaussian VaR against the analytical formula
# 5. Cross-check Cornish-Fisher VaR against the moments expansion
# 6. Visualize the return distribution with VaR / CVaR overlays

# %%
# Bootstrap: ensure the package is importable when running this notebook locally.
import sys
from pathlib import Path

ROOT = Path.cwd().parent
SRC = ROOT / "src"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

# %%
from var_cvar_crypto_risk.config import load_project_config

config = load_project_config(
    str(ROOT / "configs" / "config.yaml"),
    str(ROOT / "configs" / "assets.yaml"),
)
config["project"]
